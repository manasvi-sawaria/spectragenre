# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.regularizers import l2
import warnings
warnings.filterwarnings('ignore')

# %%
# Load 3-second features (primary dataset)
data_3s = pd.read_csv('features_3_sec.csv')
data_3s = data_3s.drop(['filename', 'length'], axis=1)
print(f"3-sec dataset: {data_3s.shape}")

# Load 30-second features (supplementary dataset)
data_30s_path = 'features_30_sec.csv'
if os.path.exists(data_30s_path):
    data_30s = pd.read_csv(data_30s_path)
    data_30s = data_30s.drop(['filename', 'length'], axis=1)
    print(f"30-sec dataset: {data_30s.shape}")
    # Combine both datasets
    data = pd.concat([data_3s, data_30s], ignore_index=True)
    print(f"Combined dataset: {data.shape}")
else:
    data = data_3s
    print("30-sec dataset not found, using 3-sec only")

print(f"\nGenres: {list(data['label'].unique())}")
print(f"\nSamples per genre:")
data['label'].value_counts()
# Out:
# 3-sec dataset: (9990, 58)
# 30-sec dataset: (1000, 58)
# Combined dataset: (10990, 58)
#
# Genres: ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
#
# Samples per genre:
# label
# blues        1100
# jazz         1100
# metal        1100
# pop          1100
# reggae       1100
# disco        1099
# classical    1098
# hiphop       1098
# rock         1098
# country      1097
# Name: count, dtype: int64

# %%
X = data.drop(['label'], axis=1)
y = data['label']

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# --- Proper 3-way split: 70% train / 15% val / 15% test ---
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X_scaled, y_encoded, test_size=0.15, random_state=42, stratify=y_encoded
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.176, random_state=42, stratify=y_train_val
)

print(f"Training samples:   {X_train.shape[0]}")
print(f"Validation samples: {X_val.shape[0]}")
print(f"Test samples:       {X_test.shape[0]}")
print(f"Features:           {X_train.shape[1]}")

# One-hot encode labels
y_train_cat = to_categorical(y_train)
y_val_cat = to_categorical(y_val)
y_test_cat = to_categorical(y_test)
num_classes = y_train_cat.shape[1]
# Out:
# Training samples:   7696
# Validation samples: 1645
# Test samples:       1649
# Features:           57

# %%
REG = l2(1e-4)  # L2 regularization strength

model = Sequential([
    # Layer 1 - Wide input layer
    Dense(512, activation='relu', input_shape=(X_train.shape[1],),
          kernel_regularizer=REG),
    BatchNormalization(),
    Dropout(0.4),

    # Layer 2
    Dense(256, activation='relu', kernel_regularizer=REG),
    BatchNormalization(),
    Dropout(0.3),

    # Layer 3
    Dense(128, activation='relu', kernel_regularizer=REG),
    BatchNormalization(),
    Dropout(0.3),

    # Layer 4
    Dense(64, activation='relu', kernel_regularizer=REG),
    BatchNormalization(),
    Dropout(0.2),

    # Output layer
    Dense(num_classes, activation='softmax')
])

# --- Label Smoothing in loss ---
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │        29,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 206,666 (807.29 KB)
#  Trainable params: 204,746 (799.79 KB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# --- Callbacks ---
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=1e-6,
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'best_ann_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=0
)

# --- Train ---
history = model.fit(
    X_train, y_train_cat,
    epochs=150,
    batch_size=32,
    validation_data=(X_val, y_val_cat),
    callbacks=[lr_scheduler, early_stop, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.4378 - loss: 1.9081 - val_accuracy: 0.6699 - val_loss: 1.3701 - learning_rate: 0.0010
# Epoch 2/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5951 - loss: 1.5017 - val_accuracy: 0.7362 - val_loss: 1.2056 - learning_rate: 0.0010
# Epoch 3/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6579 - loss: 1.3824 - val_accuracy: 0.7702 - val_loss: 1.1216 - learning_rate: 0.0010
# Epoch 4/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7061 - loss: 1.2885 - val_accuracy: 0.7988 - val_loss: 1.0695 - learning_rate: 0.0010
# Epoch 5/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7218 - loss: 1.2415 - val_accuracy: 0.8018 - val_loss: 1.0342 - learning_rate: 0.0010
# Epoch 6/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7478 - loss: 1.1856 - val_accuracy: 0.8231 - val_loss: 1.0106 - learning_rate: 0.0010
# Epoch 7/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7583 - loss: 1.1591 - val_accuracy: 0.8365 - val_loss: 0.9891 - learning_rate: 0.0010
# Epoch 8/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7799 - loss: 1.1226 - val_accuracy: 0.8444 - val_loss: 0.9757 - learning_rate: 0.0010
# Epoch 9/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7902 - loss: 1.0959 - val_accuracy: 0.8401 - val_loss: 0.9509 - learning_rate: 0.0010
# Epoch 10/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8011 - loss: 1.0659 - val_accuracy: 0.8523 - val_loss: 0.9434 - learning_rate: 0.0010
# Epoch 11/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8085 - loss: 1.0566 - val_accuracy: 0.8590 - val_loss: 0.9359 - learning_rate: 0.0010
# Epoch 12/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8157 - loss: 1.0342 - val_accuracy: 0.8657 - val_loss: 0.9181 - learning_rate: 0.0010
# Epoch 13/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8281 - loss: 1.0137 - val_accuracy: 0.8675 - val_loss: 0.9075 - learning_rate: 0.0010
# Epoch 14/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8328 - loss: 1.0101 - val_accuracy: 0.8857 - val_loss: 0.8885 - learning_rate: 0.0010
# Epoch 15/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8463 - loss: 0.9837 - val_accuracy: 0.8736 - val_loss: 0.9028 - learning_rate: 0.0010
# Epoch 16/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8472 - loss: 0.9762 - val_accuracy: 0.8863 - val_loss: 0.8790 - learning_rate: 0.0010
# Epoch 17/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8523 - loss: 0.9683 - val_accuracy: 0.8827 - val_loss: 0.8934 - learning_rate: 0.0010
# Epoch 18/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8511 - loss: 0.9707 - val_accuracy: 0.8827 - val_loss: 0.8960 - learning_rate: 0.0010
# Epoch 19/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8582 - loss: 0.9502 - val_accuracy: 0.8869 - val_loss: 0.8756 - learning_rate: 0.0010
# Epoch 20/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8703 - loss: 0.9331 - val_accuracy: 0.9021 - val_loss: 0.8523 - learning_rate: 0.0010
# Epoch 21/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8647 - loss: 0.9383 - val_accuracy: 0.8875 - val_loss: 0.8816 - learning_rate: 0.0010
# Epoch 22/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8707 - loss: 0.9315 - val_accuracy: 0.8869 - val_loss: 0.8780 - learning_rate: 0.0010
# Epoch 23/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8771 - loss: 0.9232 - val_accuracy: 0.8948 - val_loss: 0.8590 - learning_rate: 0.0010
# Epoch 24/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8823 - loss: 0.9080 - val_accuracy: 0.8997 - val_loss: 0.8527 - learning_rate: 0.0010
# Epoch 25/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8820 - loss: 0.9033 - val_accuracy: 0.9052 - val_loss: 0.8500 - learning_rate: 0.0010
# Epoch 26/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8915 - loss: 0.8918 - val_accuracy: 0.8985 - val_loss: 0.8505 - learning_rate: 0.0010
# Epoch 27/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8877 - loss: 0.8946 - val_accuracy: 0.9106 - val_loss: 0.8303 - learning_rate: 0.0010
# Epoch 28/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8898 - loss: 0.8930 - val_accuracy: 0.9009 - val_loss: 0.8452 - learning_rate: 0.0010
# Epoch 29/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8923 - loss: 0.8889 - val_accuracy: 0.9076 - val_loss: 0.8450 - learning_rate: 0.0010
# Epoch 30/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8936 - loss: 0.8810 - val_accuracy: 0.9040 - val_loss: 0.8457 - learning_rate: 0.0010
# Epoch 31/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9027 - loss: 0.8736 - val_accuracy: 0.9106 - val_loss: 0.8293 - learning_rate: 0.0010
# Epoch 32/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9055 - loss: 0.8652 - val_accuracy: 0.9040 - val_loss: 0.8429 - learning_rate: 0.0010
# Epoch 33/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9002 - loss: 0.8751 - val_accuracy: 0.9149 - val_loss: 0.8432 - learning_rate: 0.0010
# Epoch 34/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9061 - loss: 0.8626 - val_accuracy: 0.9155 - val_loss: 0.8210 - learning_rate: 0.0010
# Epoch 35/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9080 - loss: 0.8544 - val_accuracy: 0.9137 - val_loss: 0.8286 - learning_rate: 0.0010
# Epoch 36/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9071 - loss: 0.8611 - val_accuracy: 0.9179 - val_loss: 0.8252 - learning_rate: 0.0010
# Epoch 37/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9085 - loss: 0.8566 - val_accuracy: 0.9173 - val_loss: 0.8164 - learning_rate: 0.0010
# Epoch 38/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9120 - loss: 0.8483 - val_accuracy: 0.9191 - val_loss: 0.8279 - learning_rate: 0.0010
# Epoch 39/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9154 - loss: 0.8513 - val_accuracy: 0.9033 - val_loss: 0.8408 - learning_rate: 0.0010
# Epoch 40/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9133 - loss: 0.8528 - val_accuracy: 0.9070 - val_loss: 0.8457 - learning_rate: 0.0010
# Epoch 41/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9096 - loss: 0.8526 - val_accuracy: 0.9179 - val_loss: 0.8214 - learning_rate: 0.0010
# Epoch 42/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9183 - loss: 0.8421 - val_accuracy: 0.9161 - val_loss: 0.8266 - learning_rate: 0.0010
# Epoch 43/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9236 - loss: 0.8307 - val_accuracy: 0.9264 - val_loss: 0.8100 - learning_rate: 0.0010
# Epoch 44/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9236 - loss: 0.8355 - val_accuracy: 0.9234 - val_loss: 0.8188 - learning_rate: 0.0010
# Epoch 45/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9166 - loss: 0.8418 - val_accuracy: 0.9234 - val_loss: 0.8250 - learning_rate: 0.0010
# Epoch 46/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9222 - loss: 0.8401 - val_accuracy: 0.9191 - val_loss: 0.8178 - learning_rate: 0.0010
# Epoch 47/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9177 - loss: 0.8375 - val_accuracy: 0.9228 - val_loss: 0.8160 - learning_rate: 0.0010
# Epoch 48/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9206 - loss: 0.8380 - val_accuracy: 0.9252 - val_loss: 0.8116 - learning_rate: 0.0010
# Epoch 49/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9281 - loss: 0.8243 - val_accuracy: 0.9222 - val_loss: 0.8303 - learning_rate: 0.0010
# Epoch 50/150
# 240/241 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9288 - loss: 0.8295
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9298 - loss: 0.8245 - val_accuracy: 0.9258 - val_loss: 0.8214 - learning_rate: 0.0010
# Epoch 51/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9357 - loss: 0.8053 - val_accuracy: 0.9319 - val_loss: 0.7932 - learning_rate: 5.0000e-04
# Epoch 52/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9450 - loss: 0.7864 - val_accuracy: 0.9313 - val_loss: 0.7945 - learning_rate: 5.0000e-04
# Epoch 53/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9456 - loss: 0.7878 - val_accuracy: 0.9313 - val_loss: 0.7870 - learning_rate: 5.0000e-04
# Epoch 54/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9462 - loss: 0.7781 - val_accuracy: 0.9313 - val_loss: 0.7895 - learning_rate: 5.0000e-04
# Epoch 55/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9506 - loss: 0.7674 - val_accuracy: 0.9337 - val_loss: 0.7847 - learning_rate: 5.0000e-04
# Epoch 56/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9513 - loss: 0.7658 - val_accuracy: 0.9380 - val_loss: 0.7789 - learning_rate: 5.0000e-04
# Epoch 57/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9534 - loss: 0.7587 - val_accuracy: 0.9356 - val_loss: 0.7844 - learning_rate: 5.0000e-04
# Epoch 58/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9508 - loss: 0.7618 - val_accuracy: 0.9374 - val_loss: 0.7679 - learning_rate: 5.0000e-04
# Epoch 59/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9547 - loss: 0.7536 - val_accuracy: 0.9368 - val_loss: 0.7637 - learning_rate: 5.0000e-04
# Epoch 60/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9553 - loss: 0.7523 - val_accuracy: 0.9398 - val_loss: 0.7646 - learning_rate: 5.0000e-04
# Epoch 61/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9519 - loss: 0.7481 - val_accuracy: 0.9374 - val_loss: 0.7767 - learning_rate: 5.0000e-04
# Epoch 62/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9532 - loss: 0.7560 - val_accuracy: 0.9435 - val_loss: 0.7676 - learning_rate: 5.0000e-04
# Epoch 63/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9530 - loss: 0.7519 - val_accuracy: 0.9368 - val_loss: 0.7612 - learning_rate: 5.0000e-04
# Epoch 64/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9518 - loss: 0.7541 - val_accuracy: 0.9362 - val_loss: 0.7631 - learning_rate: 5.0000e-04
# Epoch 65/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9530 - loss: 0.7516 - val_accuracy: 0.9356 - val_loss: 0.7718 - learning_rate: 5.0000e-04
# Epoch 66/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9530 - loss: 0.7529 - val_accuracy: 0.9386 - val_loss: 0.7643 - learning_rate: 5.0000e-04
# Epoch 67/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9569 - loss: 0.7378 - val_accuracy: 0.9404 - val_loss: 0.7654 - learning_rate: 5.0000e-04
# Epoch 68/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9560 - loss: 0.7463 - val_accuracy: 0.9422 - val_loss: 0.7554 - learning_rate: 5.0000e-04
# Epoch 69/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9591 - loss: 0.7374 - val_accuracy: 0.9410 - val_loss: 0.7564 - learning_rate: 5.0000e-04
# Epoch 70/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9537 - loss: 0.7439 - val_accuracy: 0.9398 - val_loss: 0.7644 - learning_rate: 5.0000e-04
# Epoch 71/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9536 - loss: 0.7443 - val_accuracy: 0.9392 - val_loss: 0.7576 - learning_rate: 5.0000e-04
# Epoch 72/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9558 - loss: 0.7386 - val_accuracy: 0.9422 - val_loss: 0.7559 - learning_rate: 5.0000e-04
# Epoch 73/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9561 - loss: 0.7382 - val_accuracy: 0.9386 - val_loss: 0.7631 - learning_rate: 5.0000e-04
# Epoch 74/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9622 - loss: 0.7253 - val_accuracy: 0.9392 - val_loss: 0.7624 - learning_rate: 5.0000e-04
# Epoch 75/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9598 - loss: 0.7307 - val_accuracy: 0.9404 - val_loss: 0.7535 - learning_rate: 5.0000e-04
# Epoch 76/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9579 - loss: 0.7341 - val_accuracy: 0.9429 - val_loss: 0.7463 - learning_rate: 5.0000e-04
# Epoch 77/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9595 - loss: 0.7332 - val_accuracy: 0.9362 - val_loss: 0.7539 - learning_rate: 5.0000e-04
# Epoch 78/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9563 - loss: 0.7313 - val_accuracy: 0.9435 - val_loss: 0.7490 - learning_rate: 5.0000e-04
# Epoch 79/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9557 - loss: 0.7322 - val_accuracy: 0.9343 - val_loss: 0.7536 - learning_rate: 5.0000e-04
# Epoch 80/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9602 - loss: 0.7218 - val_accuracy: 0.9392 - val_loss: 0.7544 - learning_rate: 5.0000e-04
# Epoch 81/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9602 - loss: 0.7271 - val_accuracy: 0.9429 - val_loss: 0.7444 - learning_rate: 5.0000e-04
# Epoch 82/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9592 - loss: 0.7236 - val_accuracy: 0.9416 - val_loss: 0.7510 - learning_rate: 5.0000e-04
# Epoch 83/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9573 - loss: 0.7286 - val_accuracy: 0.9380 - val_loss: 0.7598 - learning_rate: 5.0000e-04
# Epoch 84/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9602 - loss: 0.7222 - val_accuracy: 0.9356 - val_loss: 0.7504 - learning_rate: 5.0000e-04
# Epoch 85/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9593 - loss: 0.7243 - val_accuracy: 0.9435 - val_loss: 0.7432 - learning_rate: 5.0000e-04
# Epoch 86/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9600 - loss: 0.7249 - val_accuracy: 0.9453 - val_loss: 0.7398 - learning_rate: 5.0000e-04
# Epoch 87/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9608 - loss: 0.7169 - val_accuracy: 0.9453 - val_loss: 0.7433 - learning_rate: 5.0000e-04
# Epoch 88/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9609 - loss: 0.7203 - val_accuracy: 0.9380 - val_loss: 0.7544 - learning_rate: 5.0000e-04
# Epoch 89/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9610 - loss: 0.7186 - val_accuracy: 0.9368 - val_loss: 0.7479 - learning_rate: 5.0000e-04
# Epoch 90/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9611 - loss: 0.7185 - val_accuracy: 0.9398 - val_loss: 0.7568 - learning_rate: 5.0000e-04
# Epoch 91/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9582 - loss: 0.7197 - val_accuracy: 0.9374 - val_loss: 0.7487 - learning_rate: 5.0000e-04
# Epoch 92/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9635 - loss: 0.7151 - val_accuracy: 0.9380 - val_loss: 0.7568 - learning_rate: 5.0000e-04
# Epoch 93/150
# 240/241 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9621 - loss: 0.7131
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9619 - loss: 0.7140 - val_accuracy: 0.9380 - val_loss: 0.7487 - learning_rate: 5.0000e-04
# Epoch 94/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9665 - loss: 0.7029 - val_accuracy: 0.9422 - val_loss: 0.7440 - learning_rate: 2.5000e-04
# Epoch 95/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9688 - loss: 0.6985 - val_accuracy: 0.9447 - val_loss: 0.7374 - learning_rate: 2.5000e-04
# Epoch 96/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9674 - loss: 0.6982 - val_accuracy: 0.9416 - val_loss: 0.7350 - learning_rate: 2.5000e-04
# Epoch 97/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9777 - loss: 0.6822 - val_accuracy: 0.9429 - val_loss: 0.7371 - learning_rate: 2.5000e-04
# Epoch 98/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9717 - loss: 0.6886 - val_accuracy: 0.9410 - val_loss: 0.7412 - learning_rate: 2.5000e-04
# Epoch 99/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9701 - loss: 0.6934 - val_accuracy: 0.9422 - val_loss: 0.7318 - learning_rate: 2.5000e-04
# Epoch 100/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9717 - loss: 0.6903 - val_accuracy: 0.9429 - val_loss: 0.7313 - learning_rate: 2.5000e-04
# Epoch 101/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9712 - loss: 0.6878 - val_accuracy: 0.9410 - val_loss: 0.7322 - learning_rate: 2.5000e-04
# Epoch 102/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9743 - loss: 0.6822 - val_accuracy: 0.9429 - val_loss: 0.7298 - learning_rate: 2.5000e-04
# Epoch 103/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9722 - loss: 0.6835 - val_accuracy: 0.9410 - val_loss: 0.7265 - learning_rate: 2.5000e-04
# Epoch 104/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9762 - loss: 0.6816 - val_accuracy: 0.9471 - val_loss: 0.7257 - learning_rate: 2.5000e-04
# Epoch 105/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9735 - loss: 0.6804 - val_accuracy: 0.9447 - val_loss: 0.7250 - learning_rate: 2.5000e-04
# Epoch 106/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9726 - loss: 0.6819 - val_accuracy: 0.9471 - val_loss: 0.7253 - learning_rate: 2.5000e-04
# Epoch 107/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9754 - loss: 0.6794 - val_accuracy: 0.9380 - val_loss: 0.7273 - learning_rate: 2.5000e-04
# Epoch 108/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9735 - loss: 0.6846 - val_accuracy: 0.9429 - val_loss: 0.7260 - learning_rate: 2.5000e-04
# Epoch 109/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9752 - loss: 0.6787 - val_accuracy: 0.9453 - val_loss: 0.7199 - learning_rate: 2.5000e-04
# Epoch 110/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9779 - loss: 0.6723 - val_accuracy: 0.9495 - val_loss: 0.7174 - learning_rate: 2.5000e-04
# Epoch 111/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9738 - loss: 0.6778 - val_accuracy: 0.9471 - val_loss: 0.7220 - learning_rate: 2.5000e-04
# Epoch 112/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9734 - loss: 0.6763 - val_accuracy: 0.9404 - val_loss: 0.7274 - learning_rate: 2.5000e-04
# Epoch 113/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9738 - loss: 0.6752 - val_accuracy: 0.9447 - val_loss: 0.7206 - learning_rate: 2.5000e-04
# Epoch 114/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9741 - loss: 0.6748 - val_accuracy: 0.9483 - val_loss: 0.7175 - learning_rate: 2.5000e-04
# Epoch 115/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9757 - loss: 0.6722 - val_accuracy: 0.9471 - val_loss: 0.7138 - learning_rate: 2.5000e-04
# Epoch 116/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9748 - loss: 0.6745 - val_accuracy: 0.9453 - val_loss: 0.7191 - learning_rate: 2.5000e-04
# Epoch 117/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9757 - loss: 0.6697 - val_accuracy: 0.9441 - val_loss: 0.7222 - learning_rate: 2.5000e-04
# Epoch 118/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9753 - loss: 0.6738 - val_accuracy: 0.9459 - val_loss: 0.7183 - learning_rate: 2.5000e-04
# Epoch 119/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9740 - loss: 0.6707 - val_accuracy: 0.9465 - val_loss: 0.7196 - learning_rate: 2.5000e-04
# Epoch 120/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9786 - loss: 0.6655 - val_accuracy: 0.9447 - val_loss: 0.7178 - learning_rate: 2.5000e-04
# Epoch 121/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9757 - loss: 0.6698 - val_accuracy: 0.9447 - val_loss: 0.7204 - learning_rate: 2.5000e-04
# Epoch 122/150
# 232/241 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9801 - loss: 0.6610
# Epoch 122: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9777 - loss: 0.6631 - val_accuracy: 0.9459 - val_loss: 0.7225 - learning_rate: 2.5000e-04
# Epoch 123/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9747 - loss: 0.6695 - val_accuracy: 0.9471 - val_loss: 0.7174 - learning_rate: 1.2500e-04
# Epoch 124/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9809 - loss: 0.6593 - val_accuracy: 0.9441 - val_loss: 0.7167 - learning_rate: 1.2500e-04
# Epoch 125/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9786 - loss: 0.6605 - val_accuracy: 0.9453 - val_loss: 0.7159 - learning_rate: 1.2500e-04
# Epoch 126/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9764 - loss: 0.6635 - val_accuracy: 0.9508 - val_loss: 0.7132 - learning_rate: 1.2500e-04
# Epoch 127/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9793 - loss: 0.6590 - val_accuracy: 0.9495 - val_loss: 0.7148 - learning_rate: 1.2500e-04
# Epoch 128/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9797 - loss: 0.6577 - val_accuracy: 0.9465 - val_loss: 0.7150 - learning_rate: 1.2500e-04
# Epoch 129/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9793 - loss: 0.6591 - val_accuracy: 0.9489 - val_loss: 0.7135 - learning_rate: 1.2500e-04
# Epoch 130/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9804 - loss: 0.6544 - val_accuracy: 0.9483 - val_loss: 0.7112 - learning_rate: 1.2500e-04
# Epoch 131/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9784 - loss: 0.6573 - val_accuracy: 0.9489 - val_loss: 0.7122 - learning_rate: 1.2500e-04
# Epoch 132/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9809 - loss: 0.6537 - val_accuracy: 0.9477 - val_loss: 0.7155 - learning_rate: 1.2500e-04
# Epoch 133/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9834 - loss: 0.6493 - val_accuracy: 0.9465 - val_loss: 0.7096 - learning_rate: 1.2500e-04
# Epoch 134/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9809 - loss: 0.6524 - val_accuracy: 0.9465 - val_loss: 0.7115 - learning_rate: 1.2500e-04
# Epoch 135/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9836 - loss: 0.6506 - val_accuracy: 0.9447 - val_loss: 0.7130 - learning_rate: 1.2500e-04
# Epoch 136/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9790 - loss: 0.6569 - val_accuracy: 0.9465 - val_loss: 0.7124 - learning_rate: 1.2500e-04
# Epoch 137/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9796 - loss: 0.6539 - val_accuracy: 0.9453 - val_loss: 0.7102 - learning_rate: 1.2500e-04
# Epoch 138/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9818 - loss: 0.6509 - val_accuracy: 0.9429 - val_loss: 0.7096 - learning_rate: 1.2500e-04
# Epoch 139/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9819 - loss: 0.6486 - val_accuracy: 0.9465 - val_loss: 0.7082 - learning_rate: 1.2500e-04
# Epoch 140/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9823 - loss: 0.6463 - val_accuracy: 0.9447 - val_loss: 0.7070 - learning_rate: 1.2500e-04
# Epoch 141/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9805 - loss: 0.6478 - val_accuracy: 0.9410 - val_loss: 0.7102 - learning_rate: 1.2500e-04
# Epoch 142/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9825 - loss: 0.6484 - val_accuracy: 0.9459 - val_loss: 0.7127 - learning_rate: 1.2500e-04
# Epoch 143/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9771 - loss: 0.6537 - val_accuracy: 0.9441 - val_loss: 0.7112 - learning_rate: 1.2500e-04
# Epoch 144/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9819 - loss: 0.6481 - val_accuracy: 0.9465 - val_loss: 0.7108 - learning_rate: 1.2500e-04
# Epoch 145/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9818 - loss: 0.6465 - val_accuracy: 0.9465 - val_loss: 0.7117 - learning_rate: 1.2500e-04
# Epoch 146/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9804 - loss: 0.6464 - val_accuracy: 0.9459 - val_loss: 0.7084 - learning_rate: 1.2500e-04
# Epoch 147/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9822 - loss: 0.6451 - val_accuracy: 0.9465 - val_loss: 0.7067 - learning_rate: 1.2500e-04
# Epoch 148/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9822 - loss: 0.6481 - val_accuracy: 0.9453 - val_loss: 0.7035 - learning_rate: 1.2500e-04
# Epoch 149/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9802 - loss: 0.6487 - val_accuracy: 0.9477 - val_loss: 0.7002 - learning_rate: 1.2500e-04
# Epoch 150/150
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9806 - loss: 0.6447 - val_accuracy: 0.9471 - val_loss: 0.7043 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 149.

# %%
test_loss, test_acc = model.evaluate(X_test, y_test_cat, verbose=0)

print(f"  TEST ACCURACY:  {test_acc:.4f} ({test_acc*100:.2f}%)")
print(f"  TEST LOSS:      {test_loss:.4f}")
print(f"  BEST VAL LOSS:  {min(history.history['val_loss']):.4f}")
print(f"  EPOCHS TRAINED: {len(history.history['loss'])}")
# Out:
#   TEST ACCURACY:  0.9412 (94.12%)
#   TEST LOSS:      0.7320
#   BEST VAL LOSS:  0.7002
#   EPOCHS TRAINED: 150

# %%
import librosa
from collections import Counter

# --- Feature Extraction ---
def extract_features(y, sr):
    features = []

    chroma = librosa.feature.chroma_stft(y=y, sr=sr)
    features.append(np.mean(chroma))
    features.append(np.var(chroma))

    rms = librosa.feature.rms(y=y)
    features.append(np.mean(rms))
    features.append(np.var(rms))

    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    features.append(np.mean(spec_cent))
    features.append(np.var(spec_cent))

    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    features.append(np.mean(spec_bw))
    features.append(np.var(spec_bw))

    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    features.append(np.mean(rolloff))
    features.append(np.var(rolloff))

    zcr = librosa.feature.zero_crossing_rate(y)
    features.append(np.mean(zcr))
    features.append(np.var(zcr))

    harmony = librosa.effects.harmonic(y)
    features.append(np.mean(harmony))
    features.append(np.var(harmony))

    perceptr = librosa.effects.percussive(y)
    features.append(np.mean(perceptr))
    features.append(np.var(perceptr))

    tempo = librosa.beat.tempo(y=y, sr=sr)[0]
    features.append(tempo)

    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)
    for i in range(20):
        features.append(np.mean(mfcc[i]))
        features.append(np.var(mfcc[i]))

    return np.array(features)

# --- Predict Genre ---
def predict_song(file_path):
    y, sr = librosa.load(file_path, duration=30)
    chunk_samples = 3 * sr
    predictions = []

    for i in range(10):
        start = i * chunk_samples
        end = start + chunk_samples
        chunk = y[start:end]

        if len(chunk) < chunk_samples:
            continue

        features = extract_features(chunk, sr)
        features = features.reshape(1, -1)
        features = scaler.transform(features)

        pred = model.predict(features, verbose=0)
        predictions.append(le.inverse_transform([np.argmax(pred)])[0])

    final_genre = Counter(predictions).most_common(1)[0][0]
    print(f"Chunk Predictions: {predictions}")
    print(f"Final Genre: {final_genre}")
    return final_genre

# --- Test on an audio file ---
predict_song("123.mp3")
# Out:
# Chunk Predictions: ['hiphop', 'hiphop', 'pop', 'pop', 'pop', 'pop', 'disco', 'pop', 'classical', 'hiphop']
# Final Genre: pop
# 'pop'
